# %% [markdown]
# # NGSIM.jl

# %%
using NGSIM
using AutomotiveDrivingModels
include(Pkg.dir("AutomotiveDrivingModels", "src", "viz", "AutoViz.jl"))
using AutoViz
# Out:
# INFO: Precompiling module NGSIM...

# %%
NGSIM.convert_raw_ngsim_to_trajdatas()
# Out:
# converting i101_trajectories-0750am-0805am.txt
# loading from file: elapsed time: 16.679882501 seconds
# filtering:         elapsed time: 21.684664093 seconds
# elapsed time: 58.342705902 seconds
# converting i101_trajectories-0805am-0820am.txt
# loading from file: elapsed time: 17.025204597 seconds
# filtering:         elapsed time: 20.953135766 seconds
# elapsed time: 58.749203607 seconds
# converting i101_trajectories-0820am-0835am.txt
# loading from file: elapsed time: 17.000277559 seconds
# filtering:         elapsed time: 21.121163441 seconds
# elapsed time: 60.401199869 seconds
# converting i80_trajectories-0400-0415.txt
# loading from file: elapsed time: 13.422087499 seconds
# filtering:         elapsed time: 17.55363021 seconds
# elapsed time: 43.699200382 seconds
# converting i80_trajectories-0500-0515.txt
# loading from file: elapsed time: 17.744083505 seconds
# filtering:         elapsed time: 21.683939895 seconds
# elapsed time: 55.44297872 seconds
# ...

# %%
render(ROADWAY_80)
# Out:
# Cairo.CairoSurface{UInt32}(Ptr{Void} @0x00007fedf5bde6c0,1000.0,600.0,#undef)

# %%
render(ROADWAY_101)
# Out:
# Cairo.CairoSurface{UInt32}(Ptr{Void} @0x00007fedf5fe1e50,1000.0,600.0,#undef)

# %%
render(ROADWAY_101, cam=StaticCamera(VecE2(1966600, 570700), 10.0))
# Out:
# Cairo.CairoSurface{UInt32}(Ptr{Void} @0x00007fedf5ddfed0,1000.0,600.0,#undef)

# %%
td1 = load_trajdata(1)
scene = get!(Scene(), td1, 1000)
render(scene, ROADWAY_101)
# Out:
# Cairo.CairoSurface{UInt32}(Ptr{Void} @0x00007fedf5d586c0,1000.0,600.0,#undef)

# %%
using Interact
scene = Scene()
@manipulate for i in 1000:2000
    render(get!(scene, td1, i), td1.roadway, cam=StaticCamera(VecE2(1966400, 570900), 5.0))
end
# Out:
# <script charset="utf-8">(function ($, undefined) {
#
#     function createElem(tag, attr, content) {
# 	// TODO: remove jQuery dependency
# 	var el = $("<" + tag + "/>").attr(attr);
# 	if (content) {
# 	    el.append(content);
# 	}
# 	return el[0];
#     }
#
#     // A widget must expose an id field which identifies it to the backend,
#     // an elem attribute which is will be added to the DOM, and
#     // a getState() method which returns the value to be sent to the backend
#     // a sendUpdate() method which sends its current value to the backend
#     var Widget = {
# 	id: undefined,
# 	elem: undefined,
# 	label: undefined,
# 	getState: function () {
# 	    return this.elem.value;
# 	},
# 	sendUpdate: undefined
#     };
#
#     var Slider = function (typ, id, init) {
# 	var attr = { type:  "range",
# 		     value: init.value,
# 		     min:   init.min,
# 		     max:   init.max,
# 		     step:  init.step },
# 	    elem = createElem("input", attr),
# 	    self = this;
#
# ...

# %%
scene[1].def
# Out:
# VehicleDef(493, MOTORCYCLE, 4.267, 1.951)

# %%
fieldnames(scene[1].state)
# Out:
# 3-element Array{Symbol,1}:
#  :posG
#  :posF
#  :v

# %%
fieldnames(scene[1].state.posF)
# Out:
# 4-element Array{Symbol,1}:
#  :roadind
#  :s
#  :t
#  :ϕ
